# %%
import json, urllib, requests, sys
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://www.govtrack.us/data/congress/113/votes/2013/h115/data.json'
#response = urllib.urlopen(url)
response = requests.get(url)
#data = json.loads(response.read())
#data = json_normalize(data)
data = json.loads(response.text.encode('utf8'))
df = pd.read_json(response.text)

# %%
data['votes']['Aye']
# Out:
# [{u'display_name': u'Aderholt',
#   u'id': u'A000055',
#   u'party': u'R',
#   u'state': u'AL'},
#  {u'display_name': u'Alexander',
#   u'id': u'A000361',
#   u'party': u'R',
#   u'state': u'LA'},
#  {u'display_name': u'Amash',
#   u'id': u'A000367',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Amodei',
#   u'id': u'A000369',
#   u'party': u'R',
#   u'state': u'NV'},
#  {u'display_name': u'Andrews',
#   u'id': u'A000210',
#   u'party': u'D',
#   u'state': u'NJ'},
#  {u'display_name': u'Bachus',
#   u'id': u'B000013',
#   u'party': u'R',
#   u'state': u'AL'},
#  {u'display_name': u'Barber',
#   u'id': u'B001279',
#   u'party': u'D',
#   u'state': u'AZ'},
#  {u'display_name': u'Barletta',
#   u'id': u'B001269',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Barr',
#   u'id': u'B001282',
#   u'party': u'R',
#   u'state': u'KY'},
#  {u'display_name': u'Barrow (GA)',
#   u'id': u'B001252',
#   u'party': u'D',
#   u'state': u'GA'},
#  {u'display_name': u'Barton',
#   u'id': u'B000213',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Bass',
#   u'id': u'B001270',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Beatty',
#   u'id': u'B001281',
#   u'party': u'D',
#   u'state': u'OH'},
#  {u'display_name': u'Becerra',
#   u'id': u'B000287',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Bera (CA)',
#   u'id': u'B001287',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Bilirakis',
#   u'id': u'B001257',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Bishop (GA)',
#   u'id': u'B000490',
#   u'party': u'D',
#   u'state': u'GA'},
#  {u'display_name': u'Bishop (NY)',
#   u'id': u'B001242',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Bishop (UT)',
#   u'id': u'B001250',
#   u'party': u'R',
#   u'state': u'UT'},
#  {u'display_name': u'Black',
#   u'id': u'B001273',
#   u'party': u'R',
#   u'state': u'TN'},
#  {u'display_name': u'Blumenauer',
#   u'id': u'B000574',
#   u'party': u'D',
#   u'state': u'OR'},
#  {u'display_name': u'Bonamici',
#   u'id': u'B001278',
#   u'party': u'D',
#   u'state': u'OR'},
#  {u'display_name': u'Bonner',
#   u'id': u'B001244',
#   u'party': u'R',
#   u'state': u'AL'},
#  {u'display_name': u'Boustany',
#   u'id': u'B001255',
#   u'party': u'R',
#   u'state': u'LA'},
#  {u'display_name': u'Brady (PA)',
#   u'id': u'B001227',
#   u'party': u'D',
#   u'state': u'PA'},
#  {u'display_name': u'Brady (TX)',
#   u'id': u'B000755',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Braley (IA)',
#   u'id': u'B001259',
#   u'party': u'D',
#   u'state': u'IA'},
#  {u'display_name': u'Bridenstine',
#   u'id': u'B001283',
#   u'party': u'R',
#   u'state': u'OK'},
#  {u'display_name': u'Brooks (AL)',
#   u'id': u'B001274',
#   u'party': u'R',
#   u'state': u'AL'},
#  {u'display_name': u'Brooks (IN)',
#   u'id': u'B001284',
#   u'party': u'R',
#   u'state': u'IN'},
#  {u'display_name': u'Broun (GA)',
#   u'id': u'B001262',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Brown (FL)',
#   u'id': u'B000911',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Brownley (CA)',
#   u'id': u'B001285',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Buchanan',
#   u'id': u'B001260',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Bucshon',
#   u'id': u'B001275',
#   u'party': u'R',
#   u'state': u'IN'},
#  {u'display_name': u'Burgess',
#   u'id': u'B001248',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Bustos',
#   u'id': u'B001286',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Butterfield',
#   u'id': u'B001251',
#   u'party': u'D',
#   u'state': u'NC'},
#  {u'display_name': u'Calvert',
#   u'id': u'C000059',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Camp',
#   u'id': u'C000071',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Campbell',
#   u'id': u'C001064',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Cantor',
#   u'id': u'C001046',
#   u'party': u'R',
#   u'state': u'VA'},
#  {u'display_name': u'Capito',
#   u'id': u'C001047',
#   u'party': u'R',
#   u'state': u'WV'},
#  {u'display_name': u'Capps',
#   u'id': u'C001036',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'C\xe1rdenas',
#   u'id': u'C001097',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Carney',
#   u'id': u'C001083',
#   u'party': u'D',
#   u'state': u'DE'},
#  {u'display_name': u'Carson (IN)',
#   u'id': u'C001072',
#   u'party': u'D',
#   u'state': u'IN'},
#  {u'display_name': u'Carter',
#   u'id': u'C001051',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Cartwright',
#   u'id': u'C001090',
#   u'party': u'D',
#   u'state': u'PA'},
#  {u'display_name': u'Cassidy',
#   u'id': u'C001075',
#   u'party': u'R',
#   u'state': u'LA'},
#  {u'display_name': u'Castor (FL)',
#   u'id': u'C001066',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Castro (TX)',
#   u'id': u'C001091',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Chabot',
#   u'id': u'C000266',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Chaffetz',
#   u'id': u'C001076',
#   u'party': u'R',
#   u'state': u'UT'},
#  {u'display_name': u'Chu', u'id': u'C001080', u'party': u'D', u'state': u'CA'},
#  {u'display_name': u'Cicilline',
#   u'id': u'C001084',
#   u'party': u'D',
#   u'state': u'RI'},
#  {u'display_name': u'Clarke',
#   u'id': u'C001067',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Clay',
#   u'id': u'C001049',
#   u'party': u'D',
#   u'state': u'MO'},
#  {u'display_name': u'Cleaver',
#   u'id': u'C001061',
#   u'party': u'D',
#   u'state': u'MO'},
#  {u'display_name': u'Clyburn',
#   u'id': u'C000537',
#   u'party': u'D',
#   u'state': u'SC'},
#  {u'display_name': u'Coble',
#   u'id': u'C000556',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Coffman',
#   u'id': u'C001077',
#   u'party': u'R',
#   u'state': u'CO'},
#  {u'display_name': u'Cohen',
#   u'id': u'C001068',
#   u'party': u'D',
#   u'state': u'TN'},
#  {u'display_name': u'Cole',
#   u'id': u'C001053',
#   u'party': u'R',
#   u'state': u'OK'},
#  {u'display_name': u'Collins (GA)',
#   u'id': u'C001093',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Collins (NY)',
#   u'id': u'C001092',
#   u'party': u'R',
#   u'state': u'NY'},
#  {u'display_name': u'Conaway',
#   u'id': u'C001062',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Connolly',
#   u'id': u'C001078',
#   u'party': u'D',
#   u'state': u'VA'},
#  {u'display_name': u'Conyers',
#   u'id': u'C000714',
#   u'party': u'D',
#   u'state': u'MI'},
#  {u'display_name': u'Cook',
#   u'id': u'C001094',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Cooper',
#   u'id': u'C000754',
#   u'party': u'D',
#   u'state': u'TN'},
#  {u'display_name': u'Costa',
#   u'id': u'C001059',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Cotton',
#   u'id': u'C001095',
#   u'party': u'R',
#   u'state': u'AR'},
#  {u'display_name': u'Courtney',
#   u'id': u'C001069',
#   u'party': u'D',
#   u'state': u'CT'},
#  {u'display_name': u'Cramer',
#   u'id': u'C001096',
#   u'party': u'R',
#   u'state': u'ND'},
#  {u'display_name': u'Crawford',
#   u'id': u'C001087',
#   u'party': u'R',
#   u'state': u'AR'},
#  {u'display_name': u'Crenshaw',
#   u'id': u'C001045',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Crowley',
#   u'id': u'C001038',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Cuellar',
#   u'id': u'C001063',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Culberson',
#   u'id': u'C001048',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Cummings',
#   u'id': u'C000984',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'Daines',
#   u'id': u'D000618',
#   u'party': u'R',
#   u'state': u'MT'},
#  {u'display_name': u'Davis (CA)',
#   u'id': u'D000598',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Davis, Danny',
#   u'id': u'D000096',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Davis, Rodney',
#   u'id': u'D000619',
#   u'party': u'R',
#   u'state': u'IL'},
#  {u'display_name': u'DeFazio',
#   u'id': u'D000191',
#   u'party': u'D',
#   u'state': u'OR'},
#  {u'display_name': u'DeGette',
#   u'id': u'D000197',
#   u'party': u'D',
#   u'state': u'CO'},
#  {u'display_name': u'Delaney',
#   u'id': u'D000620',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'DeLauro',
#   u'id': u'D000216',
#   u'party': u'D',
#   u'state': u'CT'},
#  {u'display_name': u'DelBene',
#   u'id': u'D000617',
#   u'party': u'D',
#   u'state': u'WA'},
#  {u'display_name': u'Denham',
#   u'id': u'D000612',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Dent',
#   u'id': u'D000604',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'DeSantis',
#   u'id': u'D000621',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'DesJarlais',
#   u'id': u'D000616',
#   u'party': u'R',
#   u'state': u'TN'},
#  {u'display_name': u'Deutch',
#   u'id': u'D000610',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Diaz-Balart',
#   u'id': u'D000600',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Dingell',
#   u'id': u'D000355',
#   u'party': u'D',
#   u'state': u'MI'},
#  {u'display_name': u'Doggett',
#   u'id': u'D000399',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Doyle',
#   u'id': u'D000482',
#   u'party': u'D',
#   u'state': u'PA'},
#  {u'display_name': u'Duckworth',
#   u'id': u'D000622',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Duffy',
#   u'id': u'D000614',
#   u'party': u'R',
#   u'state': u'WI'},
#  {u'display_name': u'Duncan (SC)',
#   u'id': u'D000615',
#   u'party': u'R',
#   u'state': u'SC'},
#  {u'display_name': u'Duncan (TN)',
#   u'id': u'D000533',
#   u'party': u'R',
#   u'state': u'TN'},
#  {u'display_name': u'Edwards',
#   u'id': u'E000290',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'Ellison',
#   u'id': u'E000288',
#   u'party': u'D',
#   u'state': u'MN'},
#  {u'display_name': u'Ellmers',
#   u'id': u'E000291',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Engel',
#   u'id': u'E000179',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Enyart',
#   u'id': u'E000292',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Eshoo',
#   u'id': u'E000215',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Esty',
#   u'id': u'E000293',
#   u'party': u'D',
#   u'state': u'CT'},
#  {u'display_name': u'Farenthold',
#   u'id': u'F000460',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Farr',
#   u'id': u'F000030',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Fattah',
#   u'id': u'F000043',
#   u'party': u'D',
#   u'state': u'PA'},
#  {u'display_name': u'Fincher',
#   u'id': u'F000458',
#   u'party': u'R',
#   u'state': u'TN'},
#  {u'display_name': u'Fitzpatrick',
#   u'id': u'F000451',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Fleischmann',
#   u'id': u'F000459',
#   u'party': u'R',
#   u'state': u'TN'},
#  {u'display_name': u'Fleming',
#   u'id': u'F000456',
#   u'party': u'R',
#   u'state': u'LA'},
#  {u'display_name': u'Flores',
#   u'id': u'F000461',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Fortenberry',
#   u'id': u'F000449',
#   u'party': u'R',
#   u'state': u'NE'},
#  {u'display_name': u'Foster',
#   u'id': u'F000454',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Foxx',
#   u'id': u'F000450',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Frankel (FL)',
#   u'id': u'F000462',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Franks (AZ)',
#   u'id': u'F000448',
#   u'party': u'R',
#   u'state': u'AZ'},
#  {u'display_name': u'Frelinghuysen',
#   u'id': u'F000372',
#   u'party': u'R',
#   u'state': u'NJ'},
#  {u'display_name': u'Fudge',
#   u'id': u'F000455',
#   u'party': u'D',
#   u'state': u'OH'},
#  {u'display_name': u'Gabbard',
#   u'id': u'G000571',
#   u'party': u'D',
#   u'state': u'HI'},
#  {u'display_name': u'Gallego',
#   u'id': u'G000572',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Garamendi',
#   u'id': u'G000559',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Garcia',
#   u'id': u'G000573',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Gardner',
#   u'id': u'G000562',
#   u'party': u'R',
#   u'state': u'CO'},
#  {u'display_name': u'Garrett',
#   u'id': u'G000548',
#   u'party': u'R',
#   u'state': u'NJ'},
#  {u'display_name': u'Gerlach',
#   u'id': u'G000549',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Gibbs',
#   u'id': u'G000563',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Gibson',
#   u'id': u'G000564',
#   u'party': u'R',
#   u'state': u'NY'},
#  {u'display_name': u'Gingrey (GA)',
#   u'id': u'G000550',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Gohmert',
#   u'id': u'G000552',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Goodlatte',
#   u'id': u'G000289',
#   u'party': u'R',
#   u'state': u'VA'},
#  {u'display_name': u'Gosar',
#   u'id': u'G000565',
#   u'party': u'R',
#   u'state': u'AZ'},
#  {u'display_name': u'Gowdy',
#   u'id': u'G000566',
#   u'party': u'R',
#   u'state': u'SC'},
#  {u'display_name': u'Granger',
#   u'id': u'G000377',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Graves (GA)',
#   u'id': u'G000560',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Graves (MO)',
#   u'id': u'G000546',
#   u'party': u'R',
#   u'state': u'MO'},
#  {u'display_name': u'Grayson',
#   u'id': u'G000556',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Green, Al',
#   u'id': u'G000553',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Green, Gene',
#   u'id': u'G000410',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Griffin (AR)',
#   u'id': u'G000567',
#   u'party': u'R',
#   u'state': u'AR'},
#  {u'display_name': u'Griffith (VA)',
#   u'id': u'G000568',
#   u'party': u'R',
#   u'state': u'VA'},
#  {u'display_name': u'Grijalva',
#   u'id': u'G000551',
#   u'party': u'D',
#   u'state': u'AZ'},
#  {u'display_name': u'Grimm',
#   u'id': u'G000569',
#   u'party': u'R',
#   u'state': u'NY'},
#  {u'display_name': u'Guthrie',
#   u'id': u'G000558',
#   u'party': u'R',
#   u'state': u'KY'},
#  {u'display_name': u'Gutierrez',
#   u'id': u'G000535',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Hahn',
#   u'id': u'H001063',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Hall',
#   u'id': u'H000067',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Hanabusa',
#   u'id': u'H001050',
#   u'party': u'D',
#   u'state': u'HI'},
#  {u'display_name': u'Hanna',
#   u'id': u'H001051',
#   u'party': u'R',
#   u'state': u'NY'},
#  {u'display_name': u'Harper',
#   u'id': u'H001045',
#   u'party': u'R',
#   u'state': u'MS'},
#  {u'display_name': u'Harris',
#   u'id': u'H001052',
#   u'party': u'R',
#   u'state': u'MD'},
#  {u'display_name': u'Hartzler',
#   u'id': u'H001053',
#   u'party': u'R',
#   u'state': u'MO'},
#  {u'display_name': u'Hastings (FL)',
#   u'id': u'H000324',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Hastings (WA)',
#   u'id': u'H000329',
#   u'party': u'R',
#   u'state': u'WA'},
#  {u'display_name': u'Heck (NV)',
#   u'id': u'H001055',
#   u'party': u'R',
#   u'state': u'NV'},
#  {u'display_name': u'Heck (WA)',
#   u'id': u'H001064',
#   u'party': u'D',
#   u'state': u'WA'},
#  {u'display_name': u'Hensarling',
#   u'id': u'H001036',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Herrera Beutler',
#   u'id': u'H001056',
#   u'party': u'R',
#   u'state': u'WA'},
#  {u'display_name': u'Higgins',
#   u'id': u'H001038',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Himes',
#   u'id': u'H001047',
#   u'party': u'D',
#   u'state': u'CT'},
#  {u'display_name': u'Hinojosa',
#   u'id': u'H000636',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Holt',
#   u'id': u'H001032',
#   u'party': u'D',
#   u'state': u'NJ'},
#  {u'display_name': u'Honda',
#   u'id': u'H001034',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Horsford',
#   u'id': u'H001066',
#   u'party': u'D',
#   u'state': u'NV'},
#  {u'display_name': u'Hoyer',
#   u'id': u'H000874',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'Hudson',
#   u'id': u'H001067',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Huelskamp',
#   u'id': u'H001057',
#   u'party': u'R',
#   u'state': u'KS'},
#  {u'display_name': u'Huffman',
#   u'id': u'H001068',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Huizenga (MI)',
#   u'id': u'H001058',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Hultgren',
#   u'id': u'H001059',
#   u'party': u'R',
#   u'state': u'IL'},
#  {u'display_name': u'Hunter',
#   u'id': u'H001048',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Hurt',
#   u'id': u'H001060',
#   u'party': u'R',
#   u'state': u'VA'},
#  {u'display_name': u'Israel',
#   u'id': u'I000057',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Issa',
#   u'id': u'I000056',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Jackson Lee',
#   u'id': u'J000032',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Jeffries',
#   u'id': u'J000294',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Jenkins',
#   u'id': u'J000290',
#   u'party': u'R',
#   u'state': u'KS'},
#  {u'display_name': u'Johnson (GA)',
#   u'id': u'J000288',
#   u'party': u'D',
#   u'state': u'GA'},
#  {u'display_name': u'Johnson (OH)',
#   u'id': u'J000292',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Johnson, E. B.',
#   u'id': u'J000126',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Johnson, Sam',
#   u'id': u'J000174',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Jones',
#   u'id': u'J000255',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Jordan',
#   u'id': u'J000289',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Joyce',
#   u'id': u'J000295',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Kaptur',
#   u'id': u'K000009',
#   u'party': u'D',
#   u'state': u'OH'},
#  {u'display_name': u'Kelly (IL)',
#   u'id': u'K000385',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Kelly (PA)',
#   u'id': u'K000376',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Kildee',
#   u'id': u'K000380',
#   u'party': u'D',
#   u'state': u'MI'},
#  {u'display_name': u'Kilmer',
#   u'id': u'K000381',
#   u'party': u'D',
#   u'state': u'WA'},
#  {u'display_name': u'Kind',
#   u'id': u'K000188',
#   u'party': u'D',
#   u'state': u'WI'},
#  {u'display_name': u'King (IA)',
#   u'id': u'K000362',
#   u'party': u'R',
#   u'state': u'IA'},
#  {u'display_name': u'King (NY)',
#   u'id': u'K000210',
#   u'party': u'R',
#   u'state': u'NY'},
#  {u'display_name': u'Kingston',
#   u'id': u'K000220',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Kinzinger (IL)',
#   u'id': u'K000378',
#   u'party': u'R',
#   u'state': u'IL'},
#  {u'display_name': u'Kirkpatrick',
#   u'id': u'K000368',
#   u'party': u'D',
#   u'state': u'AZ'},
#  {u'display_name': u'Kline',
#   u'id': u'K000363',
#   u'party': u'R',
#   u'state': u'MN'},
#  {u'display_name': u'Kuster',
#   u'id': u'K000382',
#   u'party': u'D',
#   u'state': u'NH'},
#  {u'display_name': u'Labrador',
#   u'id': u'L000573',
#   u'party': u'R',
#   u'state': u'ID'},
#  {u'display_name': u'LaMalfa',
#   u'id': u'L000578',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Lamborn',
#   u'id': u'L000564',
#   u'party': u'R',
#   u'state': u'CO'},
#  {u'display_name': u'Lance',
#   u'id': u'L000567',
#   u'party': u'R',
#   u'state': u'NJ'},
#  {u'display_name': u'Langevin',
#   u'id': u'L000559',
#   u'party': u'D',
#   u'state': u'RI'},
#  {u'display_name': u'Lankford',
#   u'id': u'L000575',
#   u'party': u'R',
#   u'state': u'OK'},
#  {u'display_name': u'Larsen (WA)',
#   u'id': u'L000560',
#   u'party': u'D',
#   u'state': u'WA'},
#  {u'display_name': u'Larson (CT)',
#   u'id': u'L000557',
#   u'party': u'D',
#   u'state': u'CT'},
#  {u'display_name': u'Latham',
#   u'id': u'L000111',
#   u'party': u'R',
#   u'state': u'IA'},
#  {u'display_name': u'Latta',
#   u'id': u'L000566',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Lee (CA)',
#   u'id': u'L000551',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Levin',
#   u'id': u'L000263',
#   u'party': u'D',
#   u'state': u'MI'},
#  {u'display_name': u'Lewis',
#   u'id': u'L000287',
#   u'party': u'D',
#   u'state': u'GA'},
#  {u'display_name': u'Lipinski',
#   u'id': u'L000563',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'LoBiondo',
#   u'id': u'L000554',
#   u'party': u'R',
#   u'state': u'NJ'},
#  {u'display_name': u'Loebsack',
#   u'id': u'L000565',
#   u'party': u'D',
#   u'state': u'IA'},
#  {u'display_name': u'Lofgren',
#   u'id': u'L000397',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Long',
#   u'id': u'L000576',
#   u'party': u'R',
#   u'state': u'MO'},
#  {u'display_name': u'Lowenthal',
#   u'id': u'L000579',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Lowey',
#   u'id': u'L000480',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Lucas',
#   u'id': u'L000491',
#   u'party': u'R',
#   u'state': u'OK'},
#  {u'display_name': u'Luetkemeyer',
#   u'id': u'L000569',
#   u'party': u'R',
#   u'state': u'MO'},
#  {u'display_name': u'Lujan Grisham (NM)',
#   u'id': u'L000580',
#   u'party': u'D',
#   u'state': u'NM'},
#  {u'display_name': u'Luj\xe1n, Ben Ray (NM)',
#   u'id': u'L000570',
#   u'party': u'D',
#   u'state': u'NM'},
#  {u'display_name': u'Lummis',
#   u'id': u'L000571',
#   u'party': u'R',
#   u'state': u'WY'},
#  {u'display_name': u'Maffei',
#   u'id': u'M001171',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Maloney, Carolyn',
#   u'id': u'M000087',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Maloney, Sean',
#   u'id': u'M001185',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Marchant',
#   u'id': u'M001158',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Marino',
#   u'id': u'M001179',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Massie',
#   u'id': u'M001184',
#   u'party': u'R',
#   u'state': u'KY'},
#  {u'display_name': u'Matheson',
#   u'id': u'M001142',
#   u'party': u'D',
#   u'state': u'UT'},
#  {u'display_name': u'Matsui',
#   u'id': u'M001163',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'McCarthy (CA)',
#   u'id': u'M001165',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'McCarthy (NY)',
#   u'id': u'M000309',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'McCaul',
#   u'id': u'M001157',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'McClintock',
#   u'id': u'M001177',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'McCollum',
#   u'id': u'M001143',
#   u'party': u'D',
#   u'state': u'MN'},
#  {u'display_name': u'McDermott',
#   u'id': u'M000404',
#   u'party': u'D',
#   u'state': u'WA'},
#  {u'display_name': u'McHenry',
#   u'id': u'M001156',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'McIntyre',
#   u'id': u'M000485',
#   u'party': u'D',
#   u'state': u'NC'},
#  {u'display_name': u'McKeon',
#   u'id': u'M000508',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'McKinley',
#   u'id': u'M001180',
#   u'party': u'R',
#   u'state': u'WV'},
#  {u'display_name': u'McMorris Rodgers',
#   u'id': u'M001159',
#   u'party': u'R',
#   u'state': u'WA'},
#  {u'display_name': u'McNerney',
#   u'id': u'M001166',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Meadows',
#   u'id': u'M001187',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Meehan',
#   u'id': u'M001181',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Meeks',
#   u'id': u'M001137',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Meng',
#   u'id': u'M001188',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Messer',
#   u'id': u'M001189',
#   u'party': u'R',
#   u'state': u'IN'},
#  {u'display_name': u'Mica',
#   u'id': u'M000689',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Michaud',
#   u'id': u'M001149',
#   u'party': u'D',
#   u'state': u'ME'},
#  {u'display_name': u'Miller (FL)',
#   u'id': u'M001144',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Miller (MI)',
#   u'id': u'M001150',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Miller, George',
#   u'id': u'M000725',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Moore',
#   u'id': u'M001160',
#   u'party': u'D',
#   u'state': u'WI'},
#  {u'display_name': u'Moran',
#   u'id': u'M000933',
#   u'party': u'D',
#   u'state': u'VA'},
#  {u'display_name': u'Mullin',
#   u'id': u'M001190',
#   u'party': u'R',
#   u'state': u'OK'},
#  {u'display_name': u'Mulvaney',
#   u'id': u'M001182',
#   u'party': u'R',
#   u'state': u'SC'},
#  {u'display_name': u'Murphy (FL)',
#   u'id': u'M001191',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Murphy (PA)',
#   u'id': u'M001151',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Nadler',
#   u'id': u'N000002',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Napolitano',
#   u'id': u'N000179',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Negrete McLeod',
#   u'id': u'N000187',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Neugebauer',
#   u'id': u'N000182',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Noem',
#   u'id': u'N000184',
#   u'party': u'R',
#   u'state': u'SD'},
#  {u'display_name': u'Nolan',
#   u'id': u'N000127',
#   u'party': u'D',
#   u'state': u'MN'},
#  {u'display_name': u'Nunes',
#   u'id': u'N000181',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Nunnelee',
#   u'id': u'N000186',
#   u'party': u'R',
#   u'state': u'MS'},
#  {u'display_name': u"O'Rourke",
#   u'id': u'O000170',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Olson',
#   u'id': u'O000168',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Owens',
#   u'id': u'O000169',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Palazzo',
#   u'id': u'P000601',
#   u'party': u'R',
#   u'state': u'MS'},
#  {u'display_name': u'Pallone',
#   u'id': u'P000034',
#   u'party': u'D',
#   u'state': u'NJ'},
#  {u'display_name': u'Pascrell',
#   u'id': u'P000096',
#   u'party': u'D',
#   u'state': u'NJ'},
#  {u'display_name': u'Pastor (AZ)',
#   u'id': u'P000099',
#   u'party': u'D',
#   u'state': u'AZ'},
#  {u'display_name': u'Paulsen',
#   u'id': u'P000594',
#   u'party': u'R',
#   u'state': u'MN'},
#  {u'display_name': u'Payne',
#   u'id': u'P000604',
#   u'party': u'D',
#   u'state': u'NJ'},
#  {u'display_name': u'Pearce',
#   u'id': u'P000588',
#   u'party': u'R',
#   u'state': u'NM'},
#  {u'display_name': u'Pelosi',
#   u'id': u'P000197',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Perlmutter',
#   u'id': u'P000593',
#   u'party': u'D',
#   u'state': u'CO'},
#  {u'display_name': u'Perry',
#   u'id': u'P000605',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Peters (CA)',
#   u'id': u'P000608',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Peters (MI)',
#   u'id': u'P000595',
#   u'party': u'D',
#   u'state': u'MI'},
#  {u'display_name': u'Peterson',
#   u'id': u'P000258',
#   u'party': u'D',
#   u'state': u'MN'},
#  {u'display_name': u'Petri',
#   u'id': u'P000265',
#   u'party': u'R',
#   u'state': u'WI'},
#  {u'display_name': u'Pingree (ME)',
#   u'id': u'P000597',
#   u'party': u'D',
#   u'state': u'ME'},
#  {u'display_name': u'Pittenger',
#   u'id': u'P000606',
#   u'party': u'R',
#   u'state': u'NC'},
#  {u'display_name': u'Pitts',
#   u'id': u'P000373',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Pocan',
#   u'id': u'P000607',
#   u'party': u'D',
#   u'state': u'WI'},
#  {u'display_name': u'Poe (TX)',
#   u'id': u'P000592',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Polis',
#   u'id': u'P000598',
#   u'party': u'D',
#   u'state': u'CO'},
#  {u'display_name': u'Pompeo',
#   u'id': u'P000602',
#   u'party': u'R',
#   u'state': u'KS'},
#  {u'display_name': u'Price (GA)',
#   u'id': u'P000591',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Price (NC)',
#   u'id': u'P000523',
#   u'party': u'D',
#   u'state': u'NC'},
#  {u'display_name': u'Quigley',
#   u'id': u'Q000023',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Radel',
#   u'id': u'R000596',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Rahall',
#   u'id': u'R000011',
#   u'party': u'D',
#   u'state': u'WV'},
#  {u'display_name': u'Rangel',
#   u'id': u'R000053',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Reed',
#   u'id': u'R000585',
#   u'party': u'R',
#   u'state': u'NY'},
#  {u'display_name': u'Reichert',
#   u'id': u'R000578',
#   u'party': u'R',
#   u'state': u'WA'},
#  {u'display_name': u'Renacci',
#   u'id': u'R000586',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Ribble',
#   u'id': u'R000587',
#   u'party': u'R',
#   u'state': u'WI'},
#  {u'display_name': u'Rice (SC)',
#   u'id': u'R000597',
#   u'party': u'R',
#   u'state': u'SC'},
#  {u'display_name': u'Richmond',
#   u'id': u'R000588',
#   u'party': u'D',
#   u'state': u'LA'},
#  {u'display_name': u'Rigell',
#   u'id': u'R000589',
#   u'party': u'R',
#   u'state': u'VA'},
#  {u'display_name': u'Roby',
#   u'id': u'R000591',
#   u'party': u'R',
#   u'state': u'AL'},
#  {u'display_name': u'Roe (TN)',
#   u'id': u'R000582',
#   u'party': u'R',
#   u'state': u'TN'},
#  {u'display_name': u'Rogers (AL)',
#   u'id': u'R000575',
#   u'party': u'R',
#   u'state': u'AL'},
#  {u'display_name': u'Rogers (KY)',
#   u'id': u'R000395',
#   u'party': u'R',
#   u'state': u'KY'},
#  {u'display_name': u'Rogers (MI)',
#   u'id': u'R000572',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Rohrabacher',
#   u'id': u'R000409',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Rokita',
#   u'id': u'R000592',
#   u'party': u'R',
#   u'state': u'IN'},
#  {u'display_name': u'Rooney',
#   u'id': u'R000583',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Ros-Lehtinen',
#   u'id': u'R000435',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Roskam',
#   u'id': u'R000580',
#   u'party': u'R',
#   u'state': u'IL'},
#  {u'display_name': u'Ross',
#   u'id': u'R000593',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Rothfus',
#   u'id': u'R000598',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Roybal-Allard',
#   u'id': u'R000486',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Royce',
#   u'id': u'R000487',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Ruiz',
#   u'id': u'R000599',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Runyan',
#   u'id': u'R000594',
#   u'party': u'R',
#   u'state': u'NJ'},
#  {u'display_name': u'Ruppersberger',
#   u'id': u'R000576',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'Rush',
#   u'id': u'R000515',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Ryan (OH)',
#   u'id': u'R000577',
#   u'party': u'D',
#   u'state': u'OH'},
#  {u'display_name': u'Ryan (WI)',
#   u'id': u'R000570',
#   u'party': u'R',
#   u'state': u'WI'},
#  {u'display_name': u'Salmon',
#   u'id': u'S000018',
#   u'party': u'R',
#   u'state': u'AZ'},
#  {u'display_name': u'S\xe1nchez, Linda T.',
#   u'id': u'S001156',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Sanchez, Loretta',
#   u'id': u'S000030',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Sarbanes',
#   u'id': u'S001168',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'Scalise',
#   u'id': u'S001176',
#   u'party': u'R',
#   u'state': u'LA'},
#  {u'display_name': u'Schakowsky',
#   u'id': u'S001145',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Schiff',
#   u'id': u'S001150',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Schneider',
#   u'id': u'S001190',
#   u'party': u'D',
#   u'state': u'IL'},
#  {u'display_name': u'Schock',
#   u'id': u'S001179',
#   u'party': u'R',
#   u'state': u'IL'},
#  {u'display_name': u'Schrader',
#   u'id': u'S001180',
#   u'party': u'D',
#   u'state': u'OR'},
#  {u'display_name': u'Schwartz',
#   u'id': u'S001162',
#   u'party': u'D',
#   u'state': u'PA'},
#  {u'display_name': u'Schweikert',
#   u'id': u'S001183',
#   u'party': u'R',
#   u'state': u'AZ'},
#  {u'display_name': u'Scott (VA)',
#   u'id': u'S000185',
#   u'party': u'D',
#   u'state': u'VA'},
#  {u'display_name': u'Scott, Austin',
#   u'id': u'S001189',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Scott, David',
#   u'id': u'S001157',
#   u'party': u'D',
#   u'state': u'GA'},
#  {u'display_name': u'Serrano',
#   u'id': u'S000248',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Sessions',
#   u'id': u'S000250',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Sewell (AL)',
#   u'id': u'S001185',
#   u'party': u'D',
#   u'state': u'AL'},
#  {u'display_name': u'Sherman',
#   u'id': u'S000344',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Shuster',
#   u'id': u'S001154',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Simpson',
#   u'id': u'S001148',
#   u'party': u'R',
#   u'state': u'ID'},
#  {u'display_name': u'Sinema',
#   u'id': u'S001191',
#   u'party': u'D',
#   u'state': u'AZ'},
#  {u'display_name': u'Sires',
#   u'id': u'S001165',
#   u'party': u'D',
#   u'state': u'NJ'},
#  {u'display_name': u'Slaughter',
#   u'id': u'S000480',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Smith (NE)',
#   u'id': u'S001172',
#   u'party': u'R',
#   u'state': u'NE'},
#  {u'display_name': u'Smith (NJ)',
#   u'id': u'S000522',
#   u'party': u'R',
#   u'state': u'NJ'},
#  {u'display_name': u'Smith (TX)',
#   u'id': u'S000583',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Smith (WA)',
#   u'id': u'S000510',
#   u'party': u'D',
#   u'state': u'WA'},
#  {u'display_name': u'Southerland',
#   u'id': u'S001186',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Speier',
#   u'id': u'S001175',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Stewart',
#   u'id': u'S001192',
#   u'party': u'R',
#   u'state': u'UT'},
#  {u'display_name': u'Stivers',
#   u'id': u'S001187',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Stockman',
#   u'id': u'S000937',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Stutzman',
#   u'id': u'S001188',
#   u'party': u'R',
#   u'state': u'IN'},
#  {u'display_name': u'Swalwell (CA)',
#   u'id': u'S001193',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Takano',
#   u'id': u'T000472',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Terry',
#   u'id': u'T000459',
#   u'party': u'R',
#   u'state': u'NE'},
#  {u'display_name': u'Thompson (CA)',
#   u'id': u'T000460',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Thompson (MS)',
#   u'id': u'T000193',
#   u'party': u'D',
#   u'state': u'MS'},
#  {u'display_name': u'Thompson (PA)',
#   u'id': u'T000467',
#   u'party': u'R',
#   u'state': u'PA'},
#  {u'display_name': u'Thornberry',
#   u'id': u'T000238',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Tiberi',
#   u'id': u'T000462',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Tipton',
#   u'id': u'T000470',
#   u'party': u'R',
#   u'state': u'CO'},
#  {u'display_name': u'Titus',
#   u'id': u'T000468',
#   u'party': u'D',
#   u'state': u'NV'},
#  {u'display_name': u'Tonko',
#   u'id': u'T000469',
#   u'party': u'D',
#   u'state': u'NY'},
#  {u'display_name': u'Turner',
#   u'id': u'T000463',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Upton',
#   u'id': u'U000031',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Valadao',
#   u'id': u'V000129',
#   u'party': u'R',
#   u'state': u'CA'},
#  {u'display_name': u'Van Hollen',
#   u'id': u'V000128',
#   u'party': u'D',
#   u'state': u'MD'},
#  {u'display_name': u'Vargas',
#   u'id': u'V000130',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Veasey',
#   u'id': u'V000131',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Vela',
#   u'id': u'V000132',
#   u'party': u'D',
#   u'state': u'TX'},
#  {u'display_name': u'Visclosky',
#   u'id': u'V000108',
#   u'party': u'D',
#   u'state': u'IN'},
#  {u'display_name': u'Wagner',
#   u'id': u'W000812',
#   u'party': u'R',
#   u'state': u'MO'},
#  {u'display_name': u'Walberg',
#   u'id': u'W000798',
#   u'party': u'R',
#   u'state': u'MI'},
#  {u'display_name': u'Walden',
#   u'id': u'W000791',
#   u'party': u'R',
#   u'state': u'OR'},
#  {u'display_name': u'Walorski',
#   u'id': u'W000813',
#   u'party': u'R',
#   u'state': u'IN'},
#  {u'display_name': u'Walz',
#   u'id': u'W000799',
#   u'party': u'D',
#   u'state': u'MN'},
#  {u'display_name': u'Wasserman Schultz',
#   u'id': u'W000797',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Waters',
#   u'id': u'W000187',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Watt',
#   u'id': u'W000207',
#   u'party': u'D',
#   u'state': u'NC'},
#  {u'display_name': u'Waxman',
#   u'id': u'W000215',
#   u'party': u'D',
#   u'state': u'CA'},
#  {u'display_name': u'Weber (TX)',
#   u'id': u'W000814',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Webster (FL)',
#   u'id': u'W000806',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Welch',
#   u'id': u'W000800',
#   u'party': u'D',
#   u'state': u'VT'},
#  {u'display_name': u'Wenstrup',
#   u'id': u'W000815',
#   u'party': u'R',
#   u'state': u'OH'},
#  {u'display_name': u'Westmoreland',
#   u'id': u'W000796',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Whitfield',
#   u'id': u'W000413',
#   u'party': u'R',
#   u'state': u'KY'},
#  {u'display_name': u'Williams',
#   u'id': u'W000816',
#   u'party': u'R',
#   u'state': u'TX'},
#  {u'display_name': u'Wilson (FL)',
#   u'id': u'W000808',
#   u'party': u'D',
#   u'state': u'FL'},
#  {u'display_name': u'Wilson (SC)',
#   u'id': u'W000795',
#   u'party': u'R',
#   u'state': u'SC'},
#  {u'display_name': u'Wittman',
#   u'id': u'W000804',
#   u'party': u'R',
#   u'state': u'VA'},
#  {u'display_name': u'Womack',
#   u'id': u'W000809',
#   u'party': u'R',
#   u'state': u'AR'},
#  {u'display_name': u'Woodall',
#   u'id': u'W000810',
#   u'party': u'R',
#   u'state': u'GA'},
#  {u'display_name': u'Yarmuth',
#   u'id': u'Y000062',
#   u'party': u'D',
#   u'state': u'KY'},
#  {u'display_name': u'Yoder',
#   u'id': u'Y000063',
#   u'party': u'R',
#   u'state': u'KS'},
#  {u'display_name': u'Yoho',
#   u'id': u'Y000065',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Young (AK)',
#   u'id': u'Y000033',
#   u'party': u'R',
#   u'state': u'AK'},
#  {u'display_name': u'Young (FL)',
#   u'id': u'Y000031',
#   u'party': u'R',
#   u'state': u'FL'},
#  {u'display_name': u'Young (IN)',
#   u'id': u'Y000064',
#   u'party': u'R',
#   u'state': u'IN'}]
